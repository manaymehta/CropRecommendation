# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("DS3.csv")
df = df.drop(["District_Name", "Crop_Year", "Area"], axis = "columns")

# %%
from sklearn.preprocessing import  StandardScaler
scaler = StandardScaler()
scaler = StandardScaler()
df['Production'] = scaler.fit_transform(df[['Production']])
df['Best_Crop'] = df.groupby(['State_Name', 'Season'])['Production'].transform(lambda x: df.loc[x.idxmax(), 'Crop'])
df = df.drop_duplicates(subset=['State_Name', 'Season'], keep='first')
df
# Out:
#                          State_Name       Season               Crop  \
# 0       Andaman and Nicobar Islands  Kharif                Arecanut
# 3       Andaman and Nicobar Islands  Whole Year              Banana
# 64      Andaman and Nicobar Islands  Autumn                    Rice
# 66      Andaman and Nicobar Islands  Rabi                  Arecanut
# 203                  Andhra Pradesh  Kharif               Arhar/Tur
# ...                             ...          ...                ...
# 236479                  West Bengal  Kharif                    Jute
# 236482                  West Bengal  Rabi                      Gram
# 236489                  West Bengal  Summer       Moong(Green Gram)
# 236491                  West Bengal  Whole Year            Arecanut
# 236504                  West Bengal  Winter                    Rice
#
#         Production       Best_Crop
# 0        -0.034016            Rice
# 3        -0.034095        Coconut
# 64       -0.034132            Rice
# ...

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier

label_encoders = {}
for col in ['State_Name', 'Season', 'Best_Crop']:
    le = LabelEncoder()
    df[f'{col}_n'] = le.fit_transform(df[col])
    label_encoders[col] = le

X = df[['State_Name_n', 'Season_n']]
y = df[['Best_Crop_n']]

print(X)
print(y)
print(label_encoders)
# Out:
#         State_Name_n  Season_n
# 0                  0         1
# 3                  0         4
# 64                 0         0
# 66                 0         2
# 203                1         1
# ...              ...       ...
# 236479            32         1
# 236482            32         2
# 236489            32         3
# 236491            32         4
# 236504            32         5
#
# [132 rows x 2 columns]
#         Best_Crop_n
# 0                18
# 3                 4
# 64               18
# 66                0
# 203              20
# ...             ...
# 236479            9
# 236482           12
# 236489           18
# 236491            4
# 236504           16
#
# [132 rows x 1 columns]
# {'State_Name': LabelEncoder(), 'Season': LabelEncoder(), 'Best_Crop': LabelEncoder()}

# %%
state_map = dict(zip(df['State_Name'], df['State_Name_n']))
season_map = dict(zip(df['Season'], df['Season_n']))
crop_map = dict(zip(df['Best_Crop_n'], df['Best_Crop']))

# Print the mappings
print("State Name Encoding:", state_map)
print("Season Encoding:", season_map)
print("Best Crop Encoding:", crop_map)
# Out:
# State Name Encoding: {'Andaman and Nicobar Islands': 0, 'Andhra Pradesh': 1, 'Arunachal Pradesh': 2, 'Assam': 3, 'Bihar': 4, 'Chandigarh': 5, 'Chhattisgarh': 6, 'Dadra and Nagar Haveli': 7, 'Goa': 8, 'Gujarat': 9, 'Haryana': 10, 'Himachal Pradesh': 11, 'Jammu and Kashmir ': 12, 'Jharkhand': 13, 'Karnataka': 14, 'Kerala': 15, 'Madhya Pradesh': 16, 'Maharashtra': 17, 'Manipur': 18, 'Meghalaya': 19, 'Mizoram': 20, 'Nagaland': 21, 'Odisha': 22, 'Puducherry': 23, 'Punjab': 24, 'Rajasthan': 25, 'Sikkim': 26, 'Tamil Nadu': 27, 'Telangana ': 28, 'Tripura': 29, 'Uttar Pradesh': 30, 'Uttarakhand': 31, 'West Bengal': 32}
# Season Encoding: {'Kharif     ': 1, 'Whole Year ': 4, 'Autumn     ': 0, 'Rabi       ': 2, 'Summer     ': 3, 'Winter     ': 5}
# ...

# %%
clf = DecisionTreeClassifier()
clf.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %%
state_input = input("Enter State Name: ")
season_input = input("Enter Season: ")
state_encoded = state_map.get(state_input)
season_encoded = season_map.get(season_input)

input_data = [[state_encoded, season_encoded]]
predicted_crop_encoded = clf.predict(input_data)[0]
best_crop_output = crop_map.get(predicted_crop_encoded)
print(best_crop_output)
# Out:
# Rice
# d:\.MANAY\MANAY\Code\Python\ML\.venv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
